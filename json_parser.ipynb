# %%
import json

# %%
import json

with open('messages.json', 'r') as dataset:
    message_data = json.load(dataset)

    # Access the "messages" key which contains a list of messages
    messages = message_data.get("messages", [])

    # Dictionary to store the first occurrence of each topic_id
    first_occurrence_dict = {}

    # Iterate through each message and print the "text" value for the first occurrence of each topic_id
    for message in messages:
        topic_id = message.get("topic_id")
        if topic_id not in first_occurrence_dict:
            first_occurrence_dict[topic_id] = message.get("text")
            #print(first_occurrence_dict[topic_id])

            # Print a separator line for better readability
            print("-" * 40)
            print(f"Topic ID: {topic_id}")
            print("Message:")
            print(first_occurrence_dict[topic_id])
# Out:
# ----------------------------------------
# Topic ID: bJf0tATJ0bk
# Message:
# Updated room membership.
# ----------------------------------------
# Topic ID: asYNgbkv57U
# Message:
# Updated room membership.
# ----------------------------------------
# Topic ID: TTYfdiAdwcE
# Message:
# Updated room membership.
# ----------------------------------------
# Topic ID: Pyn4JDnu2mk
# Message:
# Updated room membership.
# ----------------------------------------
# Topic ID: hoVSpgpHssA
# Message:
# is it possible we have an issue with our local DNS server?:
# ----------------------------------------
# Topic ID: mXJWkJCe1r4
# Message:
# Updated room membership.
# ----------------------------------------
# Topic ID: 5FgfOZaQRsA
# Message:
# Halo teman2 support,
# untuk google chat kita apakah ada setting yang tidak mengijinkan invite user diluar organisasi ?
# ada saran kah gimana buat space untuk vendor kita ?
#
# https://support.google.com/chat/answer/9301096
# ...

# %%
import json
import csv

with open('messages.json', 'r') as dataset:
    message_data = json.load(dataset)

    # Access the "messages" key which contains a list of messages
    messages = message_data.get("messages", [])

    # Dictionary to store the first occurrence of each topic_id
    first_occurrence_dict = []

    # Iterate through each message and append the data to the list
    for message in messages:
        topic_id = message.get("topic_id")
        if topic_id not in [entry["topic_id"] for entry in first_occurrence_dict]:
            first_occurrence_dict.append({
                "topic_id": topic_id,
                "message": message.get("text")
            })

    # Write the data to a CSV file
    csv_file_path = 'output.csv'
    with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
        fieldnames = ["topic_id", "message"]
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

        # Write header
        writer.writeheader()

        # Write data
        for entry in first_occurrence_dict:
            writer.writerow(entry)

#print(f"Output has been saved to {google_chat.csv}")

# %%
import json
import csv

with open('messages.json', 'r') as dataset:
    message_data = json.load(dataset)

    # Access the "messages" key which contains a list of messages
    messages = message_data.get("messages", [])

    # Dictionary to store the first occurrence of each topic_id
    first_occurrence_dict = []

    # Iterate through each message and append the data to the list
    for message in messages:
        topic_id = message.get("topic_id")
        if topic_id not in [entry["topic_id"] for entry in first_occurrence_dict]:
            creator = message.get("creator", {})
            name = creator.get("name", "")
            created_date = message.get("created_date", "")
            
            first_occurrence_dict.append({
                "topic_id": topic_id,
                "name": name,
                "created_date": created_date,
                "message": message.get("text")
            })

    # Write the data to a CSV file
    csv_file_path = 'output.csv'
    with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
        fieldnames = ["topic_id", "name", "created_date", "message"]
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

        # Write header
        writer.writeheader()

        # Write data
        for entry in first_occurrence_dict:
            writer.writerow(entry)

print(f"Output has been saved to {csv_file_path}")
# Out:
# Output has been saved to output.csv
